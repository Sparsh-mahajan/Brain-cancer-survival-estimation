# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os

# %%
df = pd.read_csv('dataset/final_df.csv')
df
# Out:
#                 Brats20ID  label1_original_shape_Elongation  \
# 0    BraTS20_Training_001                          0.731829
# 1    BraTS20_Training_002                          0.805201
# 2    BraTS20_Training_003                          0.768372
# 3    BraTS20_Training_004                          0.880563
# 4    BraTS20_Training_005                          0.342747
# ..                    ...                               ...
# 230  BraTS20_Training_363                          0.612030
# 231  BraTS20_Training_366                          0.566049
# 232  BraTS20_Training_367                          0.550380
# 233  BraTS20_Training_368                          0.529930
# 234  BraTS20_Training_369                          0.337268
#
#      label1_original_shape_Flatness  label1_original_shape_LeastAxisLength  \
# 0                          0.419790                              21.139285
# 1                          0.596898                              17.919111
# ...

# %%
df.set_index('Brats20ID', inplace=True)
df
# Out:
#                       label1_original_shape_Elongation  \
# Brats20ID
# BraTS20_Training_001                          0.731829
# BraTS20_Training_002                          0.805201
# BraTS20_Training_003                          0.768372
# BraTS20_Training_004                          0.880563
# BraTS20_Training_005                          0.342747
# ...                                                ...
# BraTS20_Training_363                          0.612030
# BraTS20_Training_366                          0.566049
# BraTS20_Training_367                          0.550380
# BraTS20_Training_368                          0.529930
# BraTS20_Training_369                          0.337268
#
#                       label1_original_shape_Flatness  \
# Brats20ID
# BraTS20_Training_001                        0.419790
# BraTS20_Training_002                        0.596898
# BraTS20_Training_003                        0.722447
# BraTS20_Training_004                        0.556199
# ...

# %%
# data type should be int but it is of type object, hence there is an outlier present
df['Survival_days']
# Out:
# Brats20ID
# BraTS20_Training_001    289
# BraTS20_Training_002    616
# BraTS20_Training_003    464
# BraTS20_Training_004    788
# BraTS20_Training_005    465
#                        ...
# BraTS20_Training_363     62
# BraTS20_Training_366    633
# BraTS20_Training_367    437
# BraTS20_Training_368    442
# BraTS20_Training_369    145
# Name: Survival_days, Length: 235, dtype: object

# %%
# find the index of the outlier
df[df['Survival_days'].apply(lambda x: str(x).isdigit() == False)]
# Out:
#                       label1_original_shape_Elongation  \
# Brats20ID
# BraTS20_Training_084                          0.598383
#
#                       label1_original_shape_Flatness  \
# Brats20ID
# BraTS20_Training_084                        0.485122
#
#                       label1_original_shape_LeastAxisLength  \
# Brats20ID
# BraTS20_Training_084                              25.220092
#
#                       label1_original_shape_MajorAxisLength  \
# Brats20ID
# BraTS20_Training_084                              51.987156
#
#                       label1_original_shape_Maximum2DDiameterColumn  \
# Brats20ID
# BraTS20_Training_084                                      41.785165
#
#                       label1_original_shape_Maximum2DDiameterRow  \
# Brats20ID
# BraTS20_Training_084                                   56.435804
#
#                       label1_original_shape_Maximum2DDiameterSlice  \
# Brats20ID
# ...

# %%
idx = df.index[df['Survival_days'].apply(lambda x: str(x).isdigit() == False)]
idx
# Out:
# Index(['BraTS20_Training_084'], dtype='object', name='Brats20ID')

# %%
df.at[idx[0], 'Survival_days']
# Out:
# 'ALIVE (361 days later)'

# %%
df.drop(idx, inplace=True)

# %%
df['Survival_days'] = df['Survival_days'].astype(int)

# %%
df.dtypes.value_counts()
# Out:
# float64    1285
# int32         1
# object        1
# dtype: int64

# %%
# one hot encode the categorical variables
df = pd.get_dummies(df, columns=['Extent_of_Resection'])
df
# Out:
#                       label1_original_shape_Elongation  \
# Brats20ID
# BraTS20_Training_001                          0.731829
# BraTS20_Training_002                          0.805201
# BraTS20_Training_003                          0.768372
# BraTS20_Training_004                          0.880563
# BraTS20_Training_005                          0.342747
# ...                                                ...
# BraTS20_Training_363                          0.612030
# BraTS20_Training_366                          0.566049
# BraTS20_Training_367                          0.550380
# BraTS20_Training_368                          0.529930
# BraTS20_Training_369                          0.337268
#
#                       label1_original_shape_Flatness  \
# Brats20ID
# BraTS20_Training_001                        0.419790
# BraTS20_Training_002                        0.596898
# BraTS20_Training_003                        0.722447
# BraTS20_Training_004                        0.556199
# ...

# %%
# finding the correlation between the features and the target variable
corr = df.corr()
# we are using abs() because we want to find the correlation between the features and the target variable irrespective of the sign
target_corr = abs(corr['Survival_days'])
# we are only interested in the features that have a correlation greater than 0.15
relevant_features = target_corr[target_corr > 0.15]
cols = relevant_features.index
# new dataframe with only the relevant features
new_df = df[cols]

# %%
relevant_features
# Out:
# label1_original_shape_LeastAxisLength             0.243200
# label1_original_shape_MajorAxisLength             0.209755
# label1_original_shape_Maximum2DDiameterColumn     0.169999
# label1_original_shape_Maximum2DDiameterRow        0.200177
# label1_original_shape_Maximum2DDiameterSlice      0.220014
#                                                     ...
# label4_original_glcm_Idmn.3                       0.231290
# label4_original_glcm_Idn.3                        0.223843
# label4_original_glrlm_GrayLevelNonUniformity.3    0.156064
# Age                                               0.353445
# Survival_days                                     1.000000
# Name: Survival_days, Length: 139, dtype: float64

# %%
# converting the survival days column to categorical data
# short term survival: 0 - 6 months i.e. 0 - 180 days
# medium term survival: 6 - 12 months i.e. 180 - 365 days
# long term survival: 12+ months i.e. 365+ days

new_df['Survival_days'] = new_df['Survival_days'].apply(lambda x: 'short' if x <= 180 else ('medium' if x <= 365 else 'long')
)
new_df
# Out:
# C:\Users\Sparsh\AppData\Local\Temp\ipykernel_18560\2215437901.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Survival_days'] = new_df['Survival_days'].apply(lambda x: 'short' if x <= 180 else ('medium' if x <= 365 else 'long')
#                       label1_original_shape_LeastAxisLength  \
# Brats20ID
# BraTS20_Training_001                              21.139285
# BraTS20_Training_002                              17.919111
# BraTS20_Training_003                              11.550058
# BraTS20_Training_004                              21.603687
# BraTS20_Training_005                              20.046940
# ...                                                     ...
# ...

# %%
# import train_test_split from sklearn
from sklearn.model_selection import train_test_split
# import minmaxscaler for scaling the data
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# import various regression models
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# import various metrics to evaluate the model
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import roc_auc_score, roc_curve, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix

# %%
X = new_df.drop(['Survival_days'], axis=1)
y = new_df[['Survival_days']]

# split the data into train and test set with a split ratio of 70:30
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# scale the training data, test data will be scaled later to prevent data leakage
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)

# %%
print('X_train_scaled shape: ', X_train_scaled.shape)
print('y_train shape: ', y_train.shape)
print('X_test shape: ', X_test.shape)
print('y_test shape: ', y_test.shape)
# Out:
# X_train_scaled shape:  (163, 138)
# y_train shape:  (163, 1)
# X_test shape:  (71, 138)
# y_test shape:  (71, 1)

# %%
def fitAndEvaluate(model, X_train_scaled, y_train, X_test, y_test, grid : list):
    # fit the model on the training data
    model.fit(X_train_scaled, y_train)
    # predict the labels of the test data
    accuracies = cross_val_score(estimator = model, X = X_train_scaled, y = y_train, cv=10)

    # scale the test data
    X_test_scaled = scaler.transform(X_test)
    y_pred = model.predict(X_test_scaled)

    print('Model accuracy score : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
    print("Cross validation: Train Score:", np.mean(accuracies))
    print("Cross validation: Test Score:", model.score(X_test, y_test))

    # plot the confusion matrix
    cm = confusion_matrix(y_test, y_pred)

    sns.set(font_scale=1.2) 
    sns.heatmap(cm, annot=True, annot_kws = {"size": 12}) 
    plt.show()

    print(classification_report(y_test, y_pred))

    # use grid search to find the best parameters
    model_grid = GridSearchCV(model, grid, cv = 5)
    model_grid.fit(X_train_scaled, y_train)

    print("Hyperparameters: ", model_grid.best_params_)
    print("Train Score: ", model_grid.best_score_)
    print("Test Score: ", model_grid.score(X_test_scaled, y_test))
    
    # return the model with best parameters
    return model_grid

# %% [markdown]
# ## 1. Using the SVM classifier

# %%
svc = SVC(C=10, kernel='rbf', gamma=1, random_state=0)
grid = {'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001]}
svc_grid = fitAndEvaluate(svc, X_train_scaled, y_train, X_test, y_test, grid)
# Out:
# c:\Users\Sparsh\Documents\GitHub\Brain cancer survival estimation\env\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Sparsh\Documents\GitHub\Brain cancer survival estimation\env\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Sparsh\Documents\GitHub\Brain cancer survival estimation\env\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# ## 2. Using the Gradient boosted classifier

# %%
boosted_clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0)
grid = {'n_estimators': [100, 200, 300, 400, 500], 'learning_rate': [0.1, 0.5, 1.0, 1.5, 2.0]}
boosted_clf_grid = fitAndEvaluate(boosted_clf, X_train_scaled, y_train, X_test, y_test, grid)
# Out:
# c:\Users\Sparsh\Documents\GitHub\Brain cancer survival estimation\env\lib\site-packages\sklearn\ensemble\_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Sparsh\Documents\GitHub\Brain cancer survival estimation\env\lib\site-packages\sklearn\ensemble\_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Sparsh\Documents\GitHub\Brain cancer survival estimation\env\lib\site-packages\sklearn\ensemble\_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# ## 3. Using the Random Forest classifier

# %%
rfc = RandomForestClassifier(n_estimators=3, random_state=0)
grid = {'n_estimators':np.arange(1,100,1), 'criterion':['gini','entropy']}
rfc_grid = fitAndEvaluate(rfc,X_train_scaled,y_train,X_test,y_test,grid)
# Out:
# C:\Users\Sparsh\AppData\Local\Temp\ipykernel_18560\3573425533.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train_scaled, y_train)
# c:\Users\Sparsh\Documents\GitHub\Brain cancer survival estimation\env\lib\site-packages\sklearn\model_selection\_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\Users\Sparsh\Documents\GitHub\Brain cancer survival estimation\env\lib\site-packages\sklearn\model_selection\_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %% [markdown]
# ## 4. Using the KNN classifier

# %%
knn  = KNeighborsClassifier(n_neighbors=38, p=2, weights='distance')
grid = {'n_neighbors':np.arange(1,75), 'p':np.arange(1,5), 'weights':['uniform','distance']}
knn_grid = fitAndEvaluate(knn,X_train_scaled,y_train,X_test,y_test,grid)
# Out:
# c:\Users\Sparsh\Documents\GitHub\Brain cancer survival estimation\env\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\Sparsh\Documents\GitHub\Brain cancer survival estimation\env\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\Sparsh\Documents\GitHub\Brain cancer survival estimation\env\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...
